# %%
import json
import requests
import yaml
from math import cos, asin, sqrt, pi

def lat_lon_distance(lat1, lon1, lat2, lon2):
    r = 6371 # km
    p = pi / 180

    a = 0.5 - cos((lat2-lat1)*p)/2 + cos(lat1*p) * cos(lat2*p) * (1-cos((lon2-lon1)*p))/2
    return 2 * r * asin(sqrt(a))

# %%
key_dict = {'key' : 'AIzaSyCthL9IcQfZDiIe2_bt0LTZQJTVkDeKR2U'} 
gmaps_key = key_dict["key"]

# %%
url = "https://maps.googleapis.com/maps/api/place/textsearch/json?"

# text string on which to search
query = "Aldi market"

# actual api key
api_key = gmaps_key
center_lat = 48.137154
center_lng = 11.576124
radius = 15000

# get method of requests module, return response object
req = requests.get(url + "location=" + str(center_lat) + "%2C" + str(center_lng) + "&query=" + query + "&radius=" + str(radius) + "&key=" + gmaps_key)

# json method of response object: json format data -> python format data
places_json = req.json()

# now result contains list of nested dictionaries
my_result = places_json["results"]

# %%
# take a look at the first element
print(my_result[0].get('formatted_address'))
print(my_result[0].get('geometry').get('location'))
print(my_result[0])
# Out:
# Hermine-von-Parish-Straße 11, 81245 München, Germany
# {'lat': 48.1504395, 'lng': 11.4762795}
# ...

# %%
i = 1
for result in my_result:
    print(f"Search result {i}\n")
    print(f"Address: {result.get('formatted_address')}\n")
    print(f"Zip: {result.get('formatted_address').split(', ')[1].split()[0]}\n")
    print(f"Lat = {result.get('geometry').get('location').get('lat')}, Lng = {result.get('geometry').get('location').get('lng')}\n")
    dist = lat_lon_distance(center_lat, center_lng, result.get('geometry').get('location').get('lat'), result.get('geometry').get('location').get('lng'))
    print(f"Distancd from Munich center = {dist}\n\n")
    i += 1
# Out:
# Search result 1
#
# Address: Hermine-von-Parish-Straße 11, 81245 München, Germany
#
# Zip: 81245
#
# Lat = 48.1504395, Lng = 11.4762795
#
# Distancd from Munich center = 7.553952004959321
#
#
# Search result 2
#
# Address: Oskar-Maria-Graf-Ring 14, 81737 München, Germany
#
# Zip: 81737
#
# Lat = 48.0982624, Lng = 11.658876
#
# Distancd from Munich center = 7.512543868133245
#
#
# Search result 3
#
# Address: Albert-Schweitzer-Straße 78, 81735 München, Germany
#
# Zip: 81735
#
# Lat = 48.1066491, Lng = 11.645865
#
# Distancd from Munich center = 6.189033900782099
#
#
# Search result 4
#
# Address: Rosenheimer Str. 30, 81669 München, Germany
#
# Zip: 81669
#
# Lat = 48.1301237, Lng = 11.5912244
#
# Distancd from Munich center = 1.366340691316694
#
#
# Search result 5
#
# Address: St.-Martin-Straße 57, 81669 München, Germany
#
# Zip: 81669
#
# Lat = 48.1207752, Lng = 11.6023464
#
# Distancd from Munich center = 2.6654231151989976
#
#
# Search result 6
#
# ...
