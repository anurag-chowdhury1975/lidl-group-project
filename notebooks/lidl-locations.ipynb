# %%
import json
import requests
import yaml
from math import cos, asin, sqrt, pi

def lat_lon_distance(lat1, lon1, lat2, lon2):
    r = 6371 # km
    p = pi / 180

    a = 0.5 - cos((lat2-lat1)*p)/2 + cos(lat1*p) * cos(lat2*p) * (1-cos((lon2-lon1)*p))/2
    return 2 * r * asin(sqrt(a))

# %%
# API key from Constructor Academy
api_key = 'AIzaSyCthL9IcQfZDiIe2_bt0LTZQJTVkDeKR2U'

keyword = 'Lidl'

# Location for Munich from google maps
location = '48.13590%2c11.58029'

# Set other parameters
radius = '15000'
type = 'supermarket'

base_url = "https://maps.googleapis.com/maps/api/place/textsearch/json"
    
params = {'keyword': keyword,
        'location': location,
        'radius': radius,
        'type': type,
        'key': api_key}

string = (base_url + 
                        '?keyword=' + params['keyword'] +
                        '&location=' + params['location'] +
                        '&radius=' + params['radius'] +
                        '&type=' + params['type'] +
                        '&key=' + params['key']                        
                       )
print(string)
request = requests.get(string)
results = request.json()

my_result = results['results']
# Out:
# https://maps.googleapis.com/maps/api/place/textsearch/json?keyword=Lidl&location=48.13590%2c11.58029&radius=15000&type=supermarket&key=AIzaSyCthL9IcQfZDiIe2_bt0LTZQJTVkDeKR2U

# %%
center_lat = 48.137154
center_lng = 11.576124

# %%
print(my_result[0].get('formatted_address'))
print(my_result[0].get('geometry').get('location'))
print(my_result[0])
# Out:
# Tal 13, 80331 München
# {'lat': 48.1363637, 'lng': 11.5790018}
# {'business_status': 'OPERATIONAL', 'formatted_address': 'Tal 13, 80331 München', 'geometry': {'location': {'lat': 48.1363637, 'lng': 11.5790018}, 'viewport': {'northeast': {'lat': 48.13756922989272, 'lng': 11.58018697989272}, 'southwest': {'lat': 48.13486957010728, 'lng': 11.57748732010728}}}, 'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png', 'icon_background_color': '#4B96F3', 'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/shoppingcart_pinlet', 'name': 'REWE', 'opening_hours': {'open_now': True}, 'photos': [{'height': 900, 'html_attributions': ['<a href="https://maps.google.com/maps/contrib/105554427539907262087">A Google User</a>'], 'photo_reference': 'AWU5eFitAcCI5f07vC-rOMNRSfyRpMr-L3j1_p8KctmcYvrk63lPcQTXpvH9iG8jNtfBJtGkldhJtiS3ynB7HT85MIiAeQsUpyIPMeETMJkSIwkRwAE30DvDOJnnFhCSNRip6Ltce6vZ8DDTpVY691Jnw2botRmBMOgWxw1VIso2VW3-9htY', 'width': 1600}], 'place_id': 'ChIJ1bojT4p1nkcRd8qWKQ3P3to', 'plus_code': {'compound_code': '4HPH+GJ Munich', 'global_code': '8FWH4HPH+GJ'}, 'rating': 4.1, 'reference': 'ChIJ1bojT4p1nkcRd8qWKQ3P3to', 'types': ['supermarket', 'grocery_or_supermarket', 'food', 'point_of_interest', 'store', 'establishment'], 'user_ratings_total': 1977}

# %%
i = 1
for result in my_result:
    print(f"Search result {i}\n")
    print(f"Address: {result.get('formatted_address')}\n")
    print(f"Zip: {result.get('formatted_address').split(', ')[1].split()[0]}\n")
    print(f"Lat = {result.get('geometry').get('location').get('lat')}, Lng = {result.get('geometry').get('location').get('lng')}\n")
    dist = lat_lon_distance(center_lat, center_lng, result.get('geometry').get('location').get('lat'), result.get('geometry').get('location').get('lng'))
    print(f"Distancd from Munich center = {dist}\n\n")
    i += 1
# Out:
# Search result 1
#
# Address: Tal 13, 80331 München
#
# Zip: 80331
#
# Lat = 48.1363637, Lng = 11.5790018
#
# Distancd from Munich center = 0.23092560218382444
#
#
# Search result 2
#
# Address: Lindwurmstraße 129, 80337 München
#
# Zip: 80337
#
# Lat = 48.12715960000001, Lng = 11.554082
#
# Distancd from Munich center = 1.9776014139248441
#
#
# Search result 3
#
# Address: Sendlinger Str. 8-10, Sendlinger Str. 10, 80331 München
#
# Zip: Sendlinger
#
# Lat = 48.1361587, Lng = 11.571191
#
# Distancd from Munich center = 0.38242546151436985
#
#
# Search result 4
#
# Address: Karlsplatz 1, 80335 München
#
# Zip: 80335
#
# Lat = 48.13811219999999, Lng = 11.5651279
#
# Distancd from Munich center = 0.8228948751536774
#
#
# Search result 5
#
# Address: Theatinerstraße 14, 80333 München
#
# Zip: 80333
#
# Lat = 48.1410106, Lng = 11.5760423
#
# Distancd from Munich center = 0.42887720202074237
#
#
# Search result 6
#
# Address: Bahnhofpl. 1, 80335 München
#
# Zip: 80335
#
# Lat = 48.1398412, Lng = 11.5615077
#
# Distancd from Munich center = 1.124994715478553
#
#
# Search result 7
#
# Address: Sendlinger Str. 46, 80331 München
#
# Zip: 80331
#
# Lat = 48.1347841, Lng = 11.5687533
#
# Distancd from Munich center = 0.6071332530744797
#
#
# Search result 8
#
# Address: Landwehrstraße 35, 80336 München
#
# Zip: 80336
#
# Lat = 48.1362429, Lng = 11.5601303
#
# Distancd from Munich center = 1.191153654965682
#
#
# Search result 9
#
# Address: Orleanspl. 10 - 12, 81667 München
#
# Zip: 81667
#
# Lat = 48.1278269, Lng = 11.604521
#
# Distancd from Munich center = 2.348794412907709
#
#
# Search result 10
#
# Address: Arnulfstraße 2, 80335 München
#
# Zip: 80335
#
# Lat = 48.14160829999999, Lng = 11.560093
#
# Distancd from Munich center = 1.2885382990059693
#
#
# Search result 11
#
# Address: Arnulfstraße 32, 80335 München
#
# Zip: 80335
#
# Lat = 48.14308010000001, Lng = 11.5559595
#
# Distancd from Munich center = 1.6349153473927758
#
#
# Search result 12
#
# Address: Grünwalder Str. 10, 81547 München
#
# Zip: 81547
#
# Lat = 48.1096946, Lng = 11.5747414
#
# Distancd from Munich center = 3.055070113294373
#
#
# Search result 13
#
# Address: Alfred-Arndt-Straße 1, 80807 München
#
# Zip: 80807
#
# Lat = 48.1827743, Lng = 11.5934473
#
# Distancd from Munich center = 5.232950411150721
#
#
# Search result 14
#
# Address: Thalkirchner Str. 190, 81371 München
#
# Zip: 81371
#
# Lat = 48.1132733, Lng = 11.5491493
#
# Distancd from Munich center = 3.325629432826215
#
#
# Search result 15
#
# Address: Plinganserstraße 45, 81369 München
#
# Zip: 81369
#
# Lat = 48.1174458, Lng = 11.5404596
#
# Distancd from Munich center = 3.4364458667312934
#
#
# Search result 16
#
# Address: Augustenstraße 78, 80333 München
#
# Zip: 80333
#
# Lat = 48.1504652, Lng = 11.5640122
#
# Distancd from Munich center = 1.7315834083571076
#
#
# Search result 17
#
# Address: Knorrstraße 83c, 80807 München
#
# Zip: 80807
#
# Lat = 48.18623299999999, Lng = 11.5721758
#
# Distancd from Munich center = 5.465187018884579
#
#
# Search result 18
#
# Address: Georgenstraße 74-78, 80799 München
#
# Zip: 80799
#
# Lat = 48.1563536, Lng = 11.5717952
#
# Distancd from Munich center = 2.1589199340795133
#
#
# Search result 19
#
# Address: Implerstraße 17, 81371 München
#
# Zip: 81371
#
# Lat = 48.1221282, Lng = 11.5500162
#
# Distancd from Munich center = 2.558511931415474
#
#
# Search result 20
#
# Address: Türkenstraße 44, 80799 München
#
# Zip: 80799
#
# Lat = 48.1489334, Lng = 11.5752291
#
# Distancd from Munich center = 1.3114914567574807
